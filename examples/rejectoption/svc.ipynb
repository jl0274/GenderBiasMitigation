# %% [markdown]
# #### This notebook demonstrates the use of the Reject Option Classification (ROC) post-processing algorithm for bias mitigation.
# - The debiasing function used is implemented in the `RejectOptionClassification` class.
# - Divide the dataset into training, validation, and testing partitions.
# - Train classifier on original training data.
# - Estimate the optimal classification threshold, that maximizes balanced accuracy without fairness constraints.
# - Estimate the optimal classification threshold, and the critical region boundary (ROC margin) using a validation set for the desired constraint on fairness. The best parameters are those that maximize the classification threshold while satisfying the fairness constraints.
# - The constraints can be used on the following fairness measures:
#     * Statistical parity difference on the predictions of the classifier
#     * Average odds difference for the classifier
#     * Equal opportunity difference for the classifier
# - Determine the prediction scores for testing data. Using the estimated optimal classification threshold, compute accuracy and fairness metrics.
# - Using the determined optimal classification threshold and the ROC margin, adjust the predictions. Report accuracy and fairness metric on the new predictions.

# %%
# %matplotlib inline
# Load all necessary packages
import sys
# sys.path.append("../")
sys.path.insert(0, '/home/jl0274/AIF360')
import numpy as np
from tqdm import tqdm
from warnings import warn

from aif360.datasets import BinaryLabelDataset
from aif360.datasets import AdultDataset
from aif360.metrics import ClassificationMetric, BinaryLabelDatasetMetric
from aif360.metrics.utils import compute_boolean_conditioning_vector
from aif360.algorithms.preprocessing.optim_preproc_helpers.data_preproc_functions\
        import load_preproc_data_adult
from aif360.algorithms.postprocessing.reject_option_classification\
        import RejectOptionClassification
from common_utils import compute_metrics

from sklearn.linear_model import SGDClassifier
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score

from IPython.display import Markdown, display
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import chi2_contingency
from statsmodels.stats.proportion import proportions_ztest
# Out:
# WARNING:root:No module named 'fairlearn': ExponentiatedGradientReduction will be unavailable. To install, run:
# pip install 'aif360[Reductions]'
# WARNING:root:No module named 'fairlearn': GridSearchReduction will be unavailable. To install, run:
# pip install 'aif360[Reductions]'
# WARNING:root:No module named 'inFairness': SenSeI and SenSR will be unavailable. To install, run:
# pip install 'aif360[inFairness]'
# WARNING:root:No module named 'fairlearn': GridSearchReduction will be unavailable. To install, run:
# pip install 'aif360[Reductions]'

# %%
import aif360
aif360.__file__
# Out:
# '/home/jl0274/AIF360/aif360/__init__.py'

# %% [markdown]
# #### Load dataset and specify options

# %%
## import dataset
dataset_used = "adult" # "adult", "german", "compas"
protected_attribute_used = 1 # 1, 2

if dataset_used == "adult":
#     dataset_orig = AdultDataset()
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        dataset_orig = load_preproc_data_adult(['sex'])
    else:
        privileged_groups = [{'race': 1}]
        unprivileged_groups = [{'race': 0}]
        dataset_orig = load_preproc_data_adult(['race'])
    
elif dataset_used == "german":
#     dataset_orig = GermanDataset()
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        dataset_orig = load_preproc_data_german(['sex'])
    else:
        privileged_groups = [{'age': 1}]
        unprivileged_groups = [{'age': 0}]
        dataset_orig = load_preproc_data_german(['age'])
    
elif dataset_used == "compas":
#     dataset_orig = CompasDataset()
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        dataset_orig = load_preproc_data_compas(['sex'])
    else:
        privileged_groups = [{'race': 1}]
        unprivileged_groups = [{'race': 0}]  
        dataset_orig = load_preproc_data_compas(['race'])

        
# Metric used (should be one of allowed_metrics)
metric_name = "Statistical parity difference"

# Upper and lower bound on the fairness metric used
metric_ub = 0.03
metric_lb = -0.03
        
#random seed for calibrated equal odds prediction
np.random.seed(1)

# Verify metric name
allowed_metrics = ["Statistical parity difference",
                   "Average odds difference",
                   "Equal opportunity difference"]
if metric_name not in allowed_metrics:
    raise ValueError("Metric name should be one of allowed metrics")
# Out:
# standard dataset: is na? False

# %% [markdown]
# #### Split into train, test and validation

# %%
# Get the dataset and split into train and test
dataset_orig_train, dataset_orig_vt = dataset_orig.split([0.7], shuffle=True)
dataset_orig_valid, dataset_orig_test = dataset_orig_vt.split([0.5], shuffle=True)

# %% [markdown]
# #### Clean up training data and display properties of the data

# %%
# print out some labels, names, etc.
display(Markdown("#### Training Dataset shape"))
print(dataset_orig_train.features.shape)
display(Markdown("#### Favorable and unfavorable labels"))
print(dataset_orig_train.favorable_label, dataset_orig_train.unfavorable_label)
display(Markdown("#### Protected attribute names"))
print(dataset_orig_train.protected_attribute_names)
display(Markdown("#### Privileged and unprivileged protected attribute values"))
print(dataset_orig_train.privileged_protected_attributes, 
      dataset_orig_train.unprivileged_protected_attributes)
display(Markdown("#### Dataset feature names"))
print(dataset_orig_train.feature_names)
# Out:
# #### Training Dataset shape
# (827046, 21)
# #### Favorable and unfavorable labels
# 1.0 0.0
# #### Protected attribute names
# ['sex']
# #### Privileged and unprivileged protected attribute values
# [array([0.])] [array([1.])]
# #### Dataset feature names
# ['hoepa_status_2.0', 'hoepa_status_3.0', 'total_loan_costs', 'rate_spread', 'interest_rate', 'origination_charges', 'lender_credits', 'derived_dwelling_category_Single Family (1-4 Units):Site-Built', 'loan_term', 'discount_points', 'construction_method_2.0', 'tract_to_msa_income_percentage', 'combined_loan_to_value_ratio', 'tract_population', 'tract_minority_population_percent', 'property_value', 'tract_owner_occupied_units', 'tract_one_to_four_family_homes', 'purchaser_type_1.0', 'income', 'sex']

# %% [markdown]
# #### Metric for original training data

# %%
metric_orig_train = BinaryLabelDatasetMetric(dataset_orig_train, 
                                             unprivileged_groups=unprivileged_groups,
                                             privileged_groups=privileged_groups)
display(Markdown("#### Original training dataset"))
print("Difference in mean outcomes between unprivileged and privileged groups = %f" % metric_orig_train.mean_difference())
# Out:
# #### Original training dataset
# Difference in mean outcomes between unprivileged and privileged groups = 0.053654

# %% [markdown]
# ## Gender Present

# %% [markdown]
# ### Train classifier on original data

# %%
# Logistic regression classifier and predictions
X_train = dataset_orig_train.features
y_train = dataset_orig_train.labels.ravel()

svc = SGDClassifier(loss='hinge', penalty=None, alpha=0.0001, verbose=True)
svc = CalibratedClassifierCV(svc, method="sigmoid", cv=5)

with tqdm(total=1, desc="Training SVC") as pbar:
    svc.fit(X_train, y_train, sample_weight=dataset_orig_train.instance_weights)
    pbar.update()

y_train_pred = svc.predict(X_train)

# positive class index
pos_ind = np.where(svc.classes_ == dataset_orig_train.favorable_label)[0][0]

dataset_orig_train_pred = dataset_orig_train.copy(deepcopy=True)
dataset_orig_train_pred.labels = y_train_pred
# Out:
# Training SVC:   0%|          | 0/1 [00:00<?, ?it/s]
# -- Epoch 1
# Norm: 56.55, NNZs: 21, Bias: 13.554622, T: 661636, Avg. loss: 0.130038
# Total training time: 0.10 seconds.
# -- Epoch 2
# Norm: 56.70, NNZs: 21, Bias: 13.595050, T: 1323272, Avg. loss: 0.111416
# Total training time: 0.20 seconds.
# -- Epoch 3
# Norm: 56.83, NNZs: 21, Bias: 13.604964, T: 1984908, Avg. loss: 0.109888
# Total training time: 0.30 seconds.
# -- Epoch 4
# Norm: 56.94, NNZs: 21, Bias: 13.601016, T: 2646544, Avg. loss: 0.109119
# Total training time: 0.40 seconds.
# -- Epoch 5
# Norm: 57.03, NNZs: 21, Bias: 13.614893, T: 3308180, Avg. loss: 0.108653
# Total training time: 0.50 seconds.
# -- Epoch 6
# Norm: 57.11, NNZs: 21, Bias: 13.622229, T: 3969816, Avg. loss: 0.108349
# Total training time: 0.60 seconds.
# -- Epoch 7
# Norm: 57.18, NNZs: 21, Bias: 13.606219, T: 4631452, Avg. loss: 0.108143
# Total training time: 0.70 seconds.
# -- Epoch 8
# Norm: 57.24, NNZs: 21, Bias: 13.617122, T: 5293088, Avg. loss: 0.107999
# Total training time: 0.80 seconds.
# Convergence after 8 epochs took 0.80 seconds
# -- Epoch 1
# Norm: 50.03, NNZs: 21, Bias: 11.145378, T: 661637, Avg. loss: 0.130550
# Total training time: 0.14 seconds.
# -- Epoch 2
# Norm: 50.20, NNZs: 21, Bias: 11.194181, T: 1323274, Avg. loss: 0.112156
# Total training time: 0.29 seconds.
# -- Epoch 3
# Norm: 50.34, NNZs: 21, Bias: 11.221727, T: 1984911, Avg. loss: 0.110612
# Total training time: 0.43 seconds.
# -- Epoch 4
# Norm: 50.46, NNZs: 21, Bias: 11.234401, T: 2646548, Avg. loss: 0.109836
# Total training time: 0.57 seconds.
# -- Epoch 5
# Norm: 50.56, NNZs: 21, Bias: 11.234100, T: 3308185, Avg. loss: 0.109359
# Total training time: 0.71 seconds.
# -- Epoch 6
# Norm: 50.65, NNZs: 21, Bias: 11.231989, T: 3969822, Avg. loss: 0.109044
# Total training time: 0.86 seconds.
# -- Epoch 7
# Norm: 50.73, NNZs: 21, Bias: 11.237365, T: 4631459, Avg. loss: 0.108831
# Total training time: 1.00 seconds.
# -- Epoch 8
# Norm: 50.80, NNZs: 21, Bias: 11.241662, T: 5293096, Avg. loss: 0.108674
# Total training time: 1.15 seconds.
# Convergence after 8 epochs took 1.15 seconds
# -- Epoch 1
# Norm: 56.66, NNZs: 21, Bias: 14.150108, T: 661637, Avg. loss: 0.131385
# Total training time: 0.10 seconds.
# -- Epoch 2
# Norm: 56.81, NNZs: 21, Bias: 14.182173, T: 1323274, Avg. loss: 0.112384
# Total training time: 0.20 seconds.
# -- Epoch 3
# Norm: 56.93, NNZs: 21, Bias: 14.189222, T: 1984911, Avg. loss: 0.110874
# Total training time: 0.30 seconds.
# -- Epoch 4
# Norm: 57.03, NNZs: 21, Bias: 14.210204, T: 2646548, Avg. loss: 0.110087
# Total training time: 0.40 seconds.
# -- Epoch 5
# Norm: 57.13, NNZs: 21, Bias: 14.203019, T: 3308185, Avg. loss: 0.109601
# Total training time: 0.50 seconds.
# -- Epoch 6
# Norm: 57.20, NNZs: 21, Bias: 14.206445, T: 3969822, Avg. loss: 0.109275
# Total training time: 0.60 seconds.
# -- Epoch 7
# Norm: 57.27, NNZs: 21, Bias: 14.215818, T: 4631459, Avg. loss: 0.109041
# Total training time: 0.70 seconds.
# -- Epoch 8
# Norm: 57.33, NNZs: 21, Bias: 14.217427, T: 5293096, Avg. loss: 0.108879
# Total training time: 0.80 seconds.
# Convergence after 8 epochs took 0.80 seconds
# -- Epoch 1
# Norm: 49.40, NNZs: 21, Bias: 11.463660, T: 661637, Avg. loss: 0.131426
# Total training time: 0.10 seconds.
# -- Epoch 2
# Norm: 49.63, NNZs: 21, Bias: 11.539359, T: 1323274, Avg. loss: 0.111778
# Total training time: 0.20 seconds.
# -- Epoch 3
# Norm: 49.80, NNZs: 21, Bias: 11.540736, T: 1984911, Avg. loss: 0.110289
# Total training time: 0.30 seconds.
# -- Epoch 4
# Norm: 49.94, NNZs: 21, Bias: 11.532234, T: 2646548, Avg. loss: 0.109559
# Total training time: 0.40 seconds.
# -- Epoch 5
# Norm: 50.05, NNZs: 21, Bias: 11.537256, T: 3308185, Avg. loss: 0.109114
# Total training time: 0.50 seconds.
# -- Epoch 6
# Norm: 50.15, NNZs: 21, Bias: 11.541144, T: 3969822, Avg. loss: 0.108830
# Total training time: 0.60 seconds.
# -- Epoch 7
# Norm: 50.23, NNZs: 21, Bias: 11.552852, T: 4631459, Avg. loss: 0.108633
# Total training time: 0.70 seconds.
# -- Epoch 8
# Norm: 50.31, NNZs: 21, Bias: 11.550518, T: 5293096, Avg. loss: 0.108496
# Total training time: 0.80 seconds.
# Convergence after 8 epochs took 0.80 seconds
# -- Epoch 1
# Norm: 51.85, NNZs: 21, Bias: 10.994492, T: 661637, Avg. loss: 0.130736
# Total training time: 0.13 seconds.
# -- Epoch 2
# Norm: 52.00, NNZs: 21, Bias: 11.050864, T: 1323274, Avg. loss: 0.111528
# Total training time: 0.24 seconds.
# -- Epoch 3
# Norm: 52.14, NNZs: 21, Bias: 11.051314, T: 1984911, Avg. loss: 0.109913
# Total training time: 0.34 seconds.
# -- Epoch 4
# Norm: 52.25, NNZs: 21, Bias: 11.069417, T: 2646548, Avg. loss: 0.109115
# Total training time: 0.44 seconds.
# -- Epoch 5
# Norm: 52.35, NNZs: 21, Bias: 11.075648, T: 3308185, Avg. loss: 0.108619
# Total training time: 0.54 seconds.
# -- Epoch 6
# Norm: 52.44, NNZs: 21, Bias: 11.077984, T: 3969822, Avg. loss: 0.108285
# Total training time: 0.64 seconds.
# -- Epoch 7
# Norm: 52.52, NNZs: 21, Bias: 11.077950, T: 4631459, Avg. loss: 0.108051
# Total training time: 0.74 seconds.
# -- Epoch 8
# Training SVC: 100%|██████████| 1/1 [00:06<00:00,  6.07s/it]
# Norm: 52.59, NNZs: 21, Bias: 11.081924, T: 5293096, Avg. loss: 0.107888
# Total training time: 0.84 seconds.
# Convergence after 8 epochs took 0.84 seconds

# %% [markdown]
# #### Obtain scores for validation and test sets

# %%
dataset_orig_valid_pred = dataset_orig_valid.copy(deepcopy=True)
X_valid = dataset_orig_valid_pred.features
y_valid = dataset_orig_valid_pred.labels
dataset_orig_valid_pred.scores = svc.predict_proba(X_valid)[:,pos_ind].reshape(-1,1)

dataset_orig_test_pred = dataset_orig_test.copy(deepcopy=True)
X_test = dataset_orig_test_pred.features
y_test = dataset_orig_test_pred.labels
dataset_orig_test_pred.scores = svc.predict_proba(X_test)[:,pos_ind].reshape(-1,1)

# %% [markdown]
# ### Find the optimal parameters from the validation set

# %% [markdown]
# #### Best threshold for classification only (no fairness)

# %%
num_thresh = 100
ba_arr = np.zeros(num_thresh)
class_thresh_arr = np.linspace(0.01, 0.99, num_thresh)
for idx, class_thresh in enumerate(class_thresh_arr):
    
    fav_inds = dataset_orig_valid_pred.scores > class_thresh
    dataset_orig_valid_pred.labels[fav_inds] = dataset_orig_valid_pred.favorable_label
    dataset_orig_valid_pred.labels[~fav_inds] = dataset_orig_valid_pred.unfavorable_label
    
    classified_metric_orig_valid = ClassificationMetric(dataset_orig_valid,
                                             dataset_orig_valid_pred, 
                                             unprivileged_groups=unprivileged_groups,
                                             privileged_groups=privileged_groups)
    
    ba_arr[idx] = 0.5*(classified_metric_orig_valid.true_positive_rate()\
                       +classified_metric_orig_valid.true_negative_rate())

best_ind = np.where(ba_arr == np.max(ba_arr))[0][0]
best_class_thresh = class_thresh_arr[best_ind]

print("Best balanced accuracy (no fairness constraints) = %.4f" % np.max(ba_arr))
print("Optimal classification threshold (no fairness constraints) = %.4f" % best_class_thresh)
# Out:
# Best balanced accuracy (no fairness constraints) = 0.9700
# Optimal classification threshold (no fairness constraints) = 0.5643

# %% [markdown]
# #### Estimate optimal parameters for the ROC method

# %%
ROC = RejectOptionClassification(unprivileged_groups=unprivileged_groups, 
                                 privileged_groups=privileged_groups, 
                                 low_class_thresh=0.01, high_class_thresh=0.99,
                                  num_class_thresh=100, num_ROC_margin=50,
                                  metric_name=metric_name,
                                  metric_ub=metric_ub, metric_lb=metric_lb)
ROC = ROC.fit(dataset_orig_valid, dataset_orig_valid_pred)

# %%
print("Optimal classification threshold (with fairness constraints) = %.4f" % ROC.classification_threshold)
print("Optimal ROC margin = %.4f" % ROC.ROC_margin)
# Out:
# Optimal classification threshold (with fairness constraints) = 0.0496
# Optimal ROC margin = 0.0010

# %% [markdown]
# ### Predictions from Validation Set

# %%
# Metrics for the test set
fav_inds = dataset_orig_valid_pred.scores > best_class_thresh
dataset_orig_valid_pred.labels[fav_inds] = dataset_orig_valid_pred.favorable_label
dataset_orig_valid_pred.labels[~fav_inds] = dataset_orig_valid_pred.unfavorable_label

display(Markdown("#### Validation set"))
display(Markdown("##### Raw predictions - No fairness constraints, only maximizing balanced accuracy"))

metric_valid_bef = compute_metrics(dataset_orig_valid, dataset_orig_valid_pred, 
                unprivileged_groups, privileged_groups)
# Out:
# #### Validation set
# ##### Raw predictions - No fairness constraints, only maximizing balanced accuracy
# Balanced accuracy = 0.9700
# Statistical parity difference = 0.0474
# Disparate impact = 1.0691
# Average odds difference = 0.0004
# Equal opportunity difference = -0.0029
# Theil index = 0.0416

# %%
# Transform the validation set
dataset_transf_valid_pred = ROC.predict(dataset_orig_valid_pred)

display(Markdown("#### Validation set"))
display(Markdown("##### Transformed predictions - With fairness constraints"))
metric_valid_aft = compute_metrics(dataset_orig_valid, dataset_transf_valid_pred, 
                unprivileged_groups, privileged_groups)
# Out:
# #### Validation set
# ##### Transformed predictions - With fairness constraints
# Balanced accuracy = 0.5501
# Statistical parity difference = 0.0282
# Disparate impact = 1.0295
# Average odds difference = 0.0444
# Equal opportunity difference = 0.0001
# Theil index = 0.0517

# %%
# Testing: Check if the metric optimized has not become worse
# assert np.abs(metric_valid_aft[metric_name]) <= np.abs(metric_valid_bef[metric_name])

# %% [markdown]
# ### Predictions from Original Test Set

# %%
display(Markdown("#### Predictions from original testing data"))
bal_acc_arr_orig = []
disp_imp_arr_orig = []
avg_odds_diff_arr_orig = []
spd_diff_arr_orig = []

print("Classification threshold used = %.4f" % best_class_thresh)
for thresh in tqdm(class_thresh_arr):
    
    if thresh == best_class_thresh:
        disp = True
    else:
        disp = False
    
    fav_inds = dataset_orig_test_pred.scores > thresh
    dataset_orig_test_pred.labels[fav_inds] = dataset_orig_test_pred.favorable_label
    dataset_orig_test_pred.labels[~fav_inds] = dataset_orig_test_pred.unfavorable_label
    
    metric_test_bef = compute_metrics(dataset_orig_test, dataset_orig_test_pred, 
                                      unprivileged_groups, privileged_groups,
                                      disp = disp)

    bal_acc_arr_orig.append(metric_test_bef["Balanced accuracy"])
    avg_odds_diff_arr_orig.append(metric_test_bef["Average odds difference"])
    disp_imp_arr_orig.append(metric_test_bef["Disparate impact"])
    spd_diff_arr_orig.append(metric_test_bef["Statistical parity difference"])
# Out:
# #### Predictions from original testing data
# Classification threshold used = 0.5643
#  58%|█████▊    | 58/100 [00:04<00:03, 12.30it/s]
# Balanced accuracy = 0.9698
# Statistical parity difference = 0.0455
# Disparate impact = 1.0662
# Average odds difference = -0.0008
# Equal opportunity difference = -0.0046
# Theil index = 0.0420
# 100%|██████████| 100/100 [00:07<00:00, 13.92it/s]

# %%
# inputs should be y_test, dataset_orig_test_pred.labels, dataset_orig_test_pred.scores respectively 
def accuracy_scores(y_true, preds, y_pred_scores, best_class_thresh):
    # F1 score
    y_pred = (y_pred_scores > best_class_thresh).astype(int)
    y_pred[y_pred == 1] = preds.favorable_label
    y_pred[y_pred == 0] = preds.unfavorable_label
    f1 = f1_score(y_true, y_pred)
    print(f"F1 Score: {f1:.4f}")
    # AUC
    auc = roc_auc_score(y_true, dataset_orig_test_pred.scores)
    print(f"ROC AUC Score: {auc:.4f}")
    
    return f1, auc
    
f1, auc = accuracy_scores(dataset_orig_test.labels, dataset_orig_test_pred, dataset_orig_test_pred.scores, best_class_thresh)
# Out:
# F1 Score: 0.9714
# ROC AUC Score: 0.9895

# %%
# bias summary metrics
def bias_summary_metrics(gender_col, target):
    # test whether loan approval significantly depends on gender
    gender_col = pd.Series(gender_col)  # Convert gender to categorical
    target = pd.Series(target.ravel())

    # Create a contingency table
    contingency_table = pd.crosstab(gender_col, target)
    
    # Perform the Chi-Square test
    chi2, p_value, dof, expected = chi2_contingency(contingency_table)
    
    print(f"Chi-Square Statistic: {chi2}")
    print(f"P-value: {p_value}")
    
    if p_value < 0.05:
        print("There is a significant association between gender and loan approval.")
    else:
        print("There is no significant association between gender and loan approval.")

    # test whether there's a significant difference in loan approval proportions across men vs women

    # Count of approvals for men and women
    men_approved = sum((gender_col == 0) & (target == 1))
    women_approved = sum((gender_col == 1) & (target == 1))
    
    # Total number of applicants in each group
    men_total = sum(gender_col == 0)
    women_total = sum(gender_col == 1)
    
    # Run the Z-test
    count = [men_approved, women_approved]
    nobs = [men_total, women_total]
    stat, p_value = proportions_ztest(count, nobs)
    
    print(f"Z-statistic: {stat}")
    print(f"P-value: {p_value:10e}")
    
    if p_value < 0.05:
        print("There is a significant difference in loan approval rates between men and women.")
    else:
        print("There is no significant difference in loan approval rates between men and women.")

    men_approved_prop = men_approved/men_total
    women_approved_prop = women_approved/women_total
    print(f'male approval rate: {men_approved_prop}')
    print(f'female approval rate: {women_approved_prop}')

# %%
bias_summary_metrics(X_test[:, -1], dataset_orig_test_pred.labels)
# Out:
# Chi-Square Statistic: 347.3483495004508
# P-value: 1.6016966173481337e-77
# There is a significant association between gender and loan approval.
# Z-statistic: 18.642745687474676
# P-value: 1.446235e-77
# There is a significant difference in loan approval rates between men and women.
# male approval rate: 0.7189440052643883
# female approval rate: 0.6765210911682757

# %%
# Metrics for the test set
fav_inds = dataset_orig_test_pred.scores > best_class_thresh
dataset_orig_test_pred.labels[fav_inds] = dataset_orig_test_pred.favorable_label
dataset_orig_test_pred.labels[~fav_inds] = dataset_orig_test_pred.unfavorable_label

display(Markdown("#### Test set"))
display(Markdown("##### Raw predictions - No fairness constraints, only maximizing balanced accuracy"))

metric_test_bef = compute_metrics(dataset_orig_test, dataset_orig_test_pred, 
                unprivileged_groups, privileged_groups)
# Out:
# #### Test set
# ##### Raw predictions - No fairness constraints, only maximizing balanced accuracy
# Balanced accuracy = 0.9698
# Statistical parity difference = 0.0455
# Disparate impact = 1.0662
# Average odds difference = -0.0008
# Equal opportunity difference = -0.0046
# Theil index = 0.0420

# %% [markdown]
# ### Graph Original Test Set

# %%
fig, ax1 = plt.subplots(figsize=(10,7))
ax1.plot(class_thresh_arr, bal_acc_arr_orig)
ax1.set_xlabel('Classification Thresholds', fontsize=16, fontweight='bold')
ax1.set_ylabel('Balanced Accuracy', color='b', fontsize=16, fontweight='bold')
ax1.xaxis.set_tick_params(labelsize=14)
ax1.yaxis.set_tick_params(labelsize=14)


ax2 = ax1.twinx()
ax2.plot(class_thresh_arr, np.abs(1.0-np.array(disp_imp_arr_orig)), color='r')
ax2.set_ylabel('abs(1-disparate impact)', color='r', fontsize=16, fontweight='bold')
ax2.axvline(best_class_thresh, color='k', linestyle=':')
ax2.yaxis.set_tick_params(labelsize=14)
ax2.grid(True)

plt.savefig("reject-xg-di-orig-gen")

plt.show()

# %% [markdown]
# ```abs(1-disparate impact)``` must be small (close to 0) for classifier predictions to be fair.
#
# However, for a classifier trained with original training data, at the best classification rate, this is quite high. This implies unfairness.

# %%
fig, ax1 = plt.subplots(figsize=(10,7))
ax1.plot(class_thresh_arr, bal_acc_arr_orig)
ax1.set_xlabel('Classification Thresholds', fontsize=16, fontweight='bold')
ax1.set_ylabel('Balanced Accuracy', color='b', fontsize=16, fontweight='bold')
ax1.xaxis.set_tick_params(labelsize=14)
ax1.yaxis.set_tick_params(labelsize=14)


ax2 = ax1.twinx()
ax2.plot(class_thresh_arr, avg_odds_diff_arr_orig, color='r')
ax2.set_ylabel('avg. odds diff.', color='r', fontsize=16, fontweight='bold')
ax2.axvline(best_class_thresh, color='k', linestyle=':')
ax2.yaxis.set_tick_params(labelsize=14)
ax2.grid(True)

plt.savefig("reject-xg-aodds-orig-gen")

plt.show()

# %% [markdown]
# ### Predictions from Transformed Test Set

# %%
# Metrics for the transformed test set
dataset_transf_test_pred = ROC.predict(dataset_orig_test_pred)

display(Markdown("#### Test set"))
display(Markdown("##### Transformed predictions - With fairness constraints"))
metric_test_aft = compute_metrics(dataset_orig_test, dataset_transf_test_pred, 
                unprivileged_groups, privileged_groups)
# Out:
# #### Test set
# ##### Transformed predictions - With fairness constraints
# Balanced accuracy = 0.5505
# Statistical parity difference = 0.0281
# Disparate impact = 1.0294
# Average odds difference = 0.0443
# Equal opportunity difference = 0.0002
# Theil index = 0.0516

# %%
display(Markdown("#### Predictions from transformed testing data"))
bal_acc_arr_transf = []
disp_imp_arr_transf = []
avg_odds_diff_arr_transf = []
spd_diff_arr_transf = []

print("Classification threshold used = %.4f" % best_class_thresh)
for thresh in tqdm(class_thresh_arr):
    
    if thresh == best_class_thresh:
        disp = True
    else:
        disp = False
    
    fav_inds = dataset_transf_test_pred.scores > thresh
    dataset_transf_test_pred.labels[fav_inds] = dataset_transf_test_pred.favorable_label
    dataset_transf_test_pred.labels[~fav_inds] = dataset_transf_test_pred.unfavorable_label
    
    metric_test_aft = compute_metrics(dataset_orig_test, dataset_transf_test_pred, 
                                      unprivileged_groups, privileged_groups,
                                      disp = disp)

    bal_acc_arr_transf.append(metric_test_aft["Balanced accuracy"])
    avg_odds_diff_arr_transf.append(metric_test_aft["Average odds difference"])
    disp_imp_arr_transf.append(metric_test_aft["Disparate impact"])
    spd_diff_arr_transf.append(metric_test_bef["Statistical parity difference"])
# Out:
# #### Predictions from transformed testing data
# Classification threshold used = 0.5643
#  58%|█████▊    | 58/100 [00:03<00:02, 14.60it/s]
# Balanced accuracy = 0.9698
# Statistical parity difference = 0.0455
# Disparate impact = 1.0662
# Average odds difference = -0.0008
# Equal opportunity difference = -0.0046
# Theil index = 0.0420
# 100%|██████████| 100/100 [00:06<00:00, 14.63it/s]

# %%
f1, auc = accuracy_scores(dataset_orig_test.labels, dataset_transf_test_pred, dataset_transf_test_pred.scores, ROC.classification_threshold)
# Out:
# F1 Score: 0.8711
# ROC AUC Score: 0.9895

# %%
bias_summary_metrics(X_test[:, -1], dataset_transf_test_pred.labels)
# Out:
# Chi-Square Statistic: 347.3483495004508
# P-value: 1.6016966173481337e-77
# There is a significant association between gender and loan approval.
# Z-statistic: 18.642745687474676
# P-value: 1.446235e-77
# There is a significant difference in loan approval rates between men and women.
# male approval rate: 0.7189440052643883
# female approval rate: 0.6765210911682757

# %% [markdown]
# ### Graph Transformed Test Set

# %%
fig, ax1 = plt.subplots(figsize=(10,7))
ax1.plot(class_thresh_arr, bal_acc_arr_transf)
ax1.set_xlabel('Classification Thresholds', fontsize=16, fontweight='bold')
ax1.set_ylabel('Balanced Accuracy', color='b', fontsize=16, fontweight='bold')
ax1.xaxis.set_tick_params(labelsize=14)
ax1.yaxis.set_tick_params(labelsize=14)


ax2 = ax1.twinx()
ax2.plot(class_thresh_arr, np.abs(1.0-np.array(disp_imp_arr_transf)), color='r')
ax2.set_ylabel('abs(1-disparate impact)', color='r', fontsize=16, fontweight='bold')
ax2.axvline(best_class_thresh, color='k', linestyle=':')
ax2.yaxis.set_tick_params(labelsize=14)
ax2.grid(True)

plt.savefig("reject-xg-di-transf-gen")

plt.show()

# %% [markdown]
# ```abs(1-disparate impact)``` must be small (close to 0) for classifier predictions to be fair.
#
# For a classifier trained with reweighted training data, at the best classification rate, this is indeed the case.
# This implies fairness.

# %%
fig, ax1 = plt.subplots(figsize=(10,7))
ax1.plot(class_thresh_arr, bal_acc_arr_transf)
ax1.set_xlabel('Classification Thresholds', fontsize=16, fontweight='bold')
ax1.set_ylabel('Balanced Accuracy', color='b', fontsize=16, fontweight='bold')
ax1.xaxis.set_tick_params(labelsize=14)
ax1.yaxis.set_tick_params(labelsize=14)


ax2 = ax1.twinx()
ax2.plot(class_thresh_arr, avg_odds_diff_arr_transf, color='r')
ax2.set_ylabel('avg. odds diff.', color='r', fontsize=16, fontweight='bold')
ax2.axvline(best_class_thresh, color='k', linestyle=':')
ax2.yaxis.set_tick_params(labelsize=14)
ax2.grid(True)

plt.savefig("reject-xg-aodds-transf-gen")

plt.show()

# %% [markdown]
# ## Gender Not Present

# %%
gender_col = X_test[:, -1]

# %%
# inputs should be y_test, dataset_orig_test_pred.labels, dataset_orig_test_pred.scores respectively 
def accuracy_scores(y_true, preds, y_pred_scores, best_class_thresh):
    # F1 score
    y_pred = (y_pred_scores > best_class_thresh).astype(int)
    y_pred[y_pred == 1] = preds.favorable_label
    y_pred[y_pred == 0] = preds.unfavorable_label
    f1 = f1_score(y_true, y_pred)
    print(f"F1 Score: {f1:.4f}")
    # AUC
    auc = roc_auc_score(y_true, dataset_orig_test_pred.scores)
    print(f"ROC AUC Score: {auc:.4f}")
    
    return f1, auc

# %% [markdown]
# ### Train classifier on original data

# %%
# Logistic regression classifier and predictions
X_train = dataset_orig_train.features[:, :-1]
y_train = dataset_orig_train.labels.ravel()

svc = SGDClassifier(loss='hinge', penalty=None, alpha=0.0001, verbose=True)
svc = CalibratedClassifierCV(svc, method="sigmoid", cv=5)

with tqdm(total=1, desc="Training SVC") as pbar:
    svc.fit(X_train, y_train, sample_weight=dataset_orig_train.instance_weights)
    pbar.update()

y_train_pred = svc.predict(X_train)

# positive class index
pos_ind = np.where(svc.classes_ == dataset_orig_train.favorable_label)[0][0]

dataset_orig_train_pred = dataset_orig_train.copy(deepcopy=True)
dataset_orig_train_pred.labels = y_train_pred
# Out:
# Training SVC:   0%|          | 0/1 [00:00<?, ?it/s]
# -- Epoch 1
# Norm: 45.82, NNZs: 20, Bias: 11.189686, T: 661636, Avg. loss: 0.129261
# Total training time: 0.10 seconds.
# -- Epoch 2
# Norm: 46.01, NNZs: 20, Bias: 11.232187, T: 1323272, Avg. loss: 0.111201
# Total training time: 0.20 seconds.
# -- Epoch 3
# Norm: 46.18, NNZs: 20, Bias: 11.217779, T: 1984908, Avg. loss: 0.109687
# Total training time: 0.30 seconds.
# -- Epoch 4
# Norm: 46.32, NNZs: 20, Bias: 11.228283, T: 2646544, Avg. loss: 0.108905
# Total training time: 0.40 seconds.
# -- Epoch 5
# Norm: 46.44, NNZs: 20, Bias: 11.238878, T: 3308180, Avg. loss: 0.108412
# Total training time: 0.50 seconds.
# -- Epoch 6
# Norm: 46.54, NNZs: 20, Bias: 11.236534, T: 3969816, Avg. loss: 0.108097
# Total training time: 0.59 seconds.
# -- Epoch 7
# Norm: 46.63, NNZs: 20, Bias: 11.252515, T: 4631452, Avg. loss: 0.107882
# Total training time: 0.69 seconds.
# -- Epoch 8
# Norm: 46.71, NNZs: 20, Bias: 11.247752, T: 5293088, Avg. loss: 0.107735
# Total training time: 0.79 seconds.
# Convergence after 8 epochs took 0.79 seconds
# -- Epoch 1
# Norm: 47.17, NNZs: 20, Bias: 10.846552, T: 661637, Avg. loss: 0.129052
# Total training time: 0.10 seconds.
# -- Epoch 2
# Norm: 47.43, NNZs: 20, Bias: 10.900661, T: 1323274, Avg. loss: 0.111385
# Total training time: 0.20 seconds.
# -- Epoch 3
# Norm: 47.62, NNZs: 20, Bias: 10.903675, T: 1984911, Avg. loss: 0.110031
# Total training time: 0.30 seconds.
# -- Epoch 4
# Norm: 47.77, NNZs: 20, Bias: 10.922349, T: 2646548, Avg. loss: 0.109370
# Total training time: 0.40 seconds.
# -- Epoch 5
# Norm: 47.89, NNZs: 20, Bias: 10.925311, T: 3308185, Avg. loss: 0.108994
# Total training time: 0.49 seconds.
# -- Epoch 6
# Norm: 47.99, NNZs: 20, Bias: 10.915141, T: 3969822, Avg. loss: 0.108749
# Total training time: 0.59 seconds.
# -- Epoch 7
# Norm: 48.08, NNZs: 20, Bias: 10.921040, T: 4631459, Avg. loss: 0.108586
# Total training time: 0.69 seconds.
# -- Epoch 8
# Norm: 48.16, NNZs: 20, Bias: 10.921829, T: 5293096, Avg. loss: 0.108464
# Total training time: 0.79 seconds.
# Convergence after 8 epochs took 0.79 seconds
# -- Epoch 1
# Norm: 48.97, NNZs: 20, Bias: 10.787191, T: 661637, Avg. loss: 0.130089
# Total training time: 0.10 seconds.
# -- Epoch 2
# Norm: 49.12, NNZs: 20, Bias: 10.831553, T: 1323274, Avg. loss: 0.112310
# Total training time: 0.20 seconds.
# -- Epoch 3
# Norm: 49.26, NNZs: 20, Bias: 10.837570, T: 1984911, Avg. loss: 0.110811
# Total training time: 0.30 seconds.
# -- Epoch 4
# Norm: 49.38, NNZs: 20, Bias: 10.854391, T: 2646548, Avg. loss: 0.110018
# Total training time: 0.40 seconds.
# -- Epoch 5
# Norm: 49.48, NNZs: 20, Bias: 10.868944, T: 3308185, Avg. loss: 0.109533
# Total training time: 0.50 seconds.
# -- Epoch 6
# Norm: 49.57, NNZs: 20, Bias: 10.871797, T: 3969822, Avg. loss: 0.109202
# Total training time: 0.60 seconds.
# -- Epoch 7
# Norm: 49.65, NNZs: 20, Bias: 10.878581, T: 4631459, Avg. loss: 0.108974
# Total training time: 0.70 seconds.
# -- Epoch 8
# Norm: 49.72, NNZs: 20, Bias: 10.876347, T: 5293096, Avg. loss: 0.108812
# Total training time: 0.80 seconds.
# Convergence after 8 epochs took 0.80 seconds
# -- Epoch 1
# Norm: 49.85, NNZs: 20, Bias: 10.756132, T: 661637, Avg. loss: 0.130564
# Total training time: 0.10 seconds.
# -- Epoch 2
# Norm: 49.99, NNZs: 20, Bias: 10.813783, T: 1323274, Avg. loss: 0.112191
# Total training time: 0.20 seconds.
# -- Epoch 3
# Norm: 50.13, NNZs: 20, Bias: 10.814742, T: 1984911, Avg. loss: 0.110633
# Total training time: 0.30 seconds.
# -- Epoch 4
# Norm: 50.25, NNZs: 20, Bias: 10.829287, T: 2646548, Avg. loss: 0.109838
# Total training time: 0.40 seconds.
# -- Epoch 5
# Norm: 50.35, NNZs: 20, Bias: 10.833331, T: 3308185, Avg. loss: 0.109336
# Total training time: 0.50 seconds.
# -- Epoch 6
# Norm: 50.44, NNZs: 20, Bias: 10.841818, T: 3969822, Avg. loss: 0.109009
# Total training time: 0.59 seconds.
# -- Epoch 7
# Norm: 50.52, NNZs: 20, Bias: 10.837518, T: 4631459, Avg. loss: 0.108780
# Total training time: 0.69 seconds.
# -- Epoch 8
# Norm: 50.60, NNZs: 20, Bias: 10.840213, T: 5293096, Avg. loss: 0.108620
# Total training time: 0.79 seconds.
# Convergence after 8 epochs took 0.79 seconds
# -- Epoch 1
# Norm: 46.66, NNZs: 20, Bias: 11.061520, T: 661637, Avg. loss: 0.128227
# Total training time: 0.10 seconds.
# -- Epoch 2
# Norm: 46.86, NNZs: 20, Bias: 11.072407, T: 1323274, Avg. loss: 0.111117
# Total training time: 0.20 seconds.
# -- Epoch 3
# Norm: 47.02, NNZs: 20, Bias: 11.092965, T: 1984911, Avg. loss: 0.109617
# Total training time: 0.30 seconds.
# -- Epoch 4
# Norm: 47.16, NNZs: 20, Bias: 11.106225, T: 2646548, Avg. loss: 0.108823
# Total training time: 0.40 seconds.
# -- Epoch 5
# Norm: 47.28, NNZs: 20, Bias: 11.112505, T: 3308185, Avg. loss: 0.108311
# Total training time: 0.50 seconds.
# -- Epoch 6
# Norm: 47.38, NNZs: 20, Bias: 11.114979, T: 3969822, Avg. loss: 0.107972
# Total training time: 0.60 seconds.
# -- Epoch 7
# Norm: 47.48, NNZs: 20, Bias: 11.117188, T: 4631459, Avg. loss: 0.107741
# Total training time: 0.70 seconds.
# -- Epoch 8
# Norm: 47.56, NNZs: 20, Bias: 11.117289, T: 5293096, Avg. loss: 0.107574
# Total training time: 0.79 seconds.
# Convergence after 8 epochs took 0.79 seconds
# Training SVC: 100%|██████████| 1/1 [00:05<00:00,  5.51s/it]

# %% [markdown]
# #### Obtain scores for validation and test sets

# %%
dataset_orig_valid_pred = dataset_orig_valid.copy(deepcopy=True)
X_valid = dataset_orig_valid_pred.features[:, :-1]
y_valid = dataset_orig_valid_pred.labels
dataset_orig_valid_pred.scores = svc.predict_proba(X_valid)[:,pos_ind].reshape(-1,1)

dataset_orig_test_pred = dataset_orig_test.copy(deepcopy=True)
X_test = dataset_orig_test_pred.features[:, :-1]
y_test = dataset_orig_test_pred.labels
dataset_orig_test_pred.scores = svc.predict_proba(X_test)[:,pos_ind].reshape(-1,1)

# %% [markdown]
# ### Find the optimal parameters from the validation set

# %% [markdown]
# #### Best threshold for classification only (no fairness)

# %%
num_thresh = 100
ba_arr = np.zeros(num_thresh)
class_thresh_arr = np.linspace(0.01, 0.99, num_thresh)
for idx, class_thresh in enumerate(class_thresh_arr):
    
    fav_inds = dataset_orig_valid_pred.scores > class_thresh
    dataset_orig_valid_pred.labels[fav_inds] = dataset_orig_valid_pred.favorable_label
    dataset_orig_valid_pred.labels[~fav_inds] = dataset_orig_valid_pred.unfavorable_label
    
    classified_metric_orig_valid = ClassificationMetric(dataset_orig_valid,
                                             dataset_orig_valid_pred, 
                                             unprivileged_groups=unprivileged_groups,
                                             privileged_groups=privileged_groups)
    
    ba_arr[idx] = 0.5*(classified_metric_orig_valid.true_positive_rate()\
                       +classified_metric_orig_valid.true_negative_rate())

best_ind = np.where(ba_arr == np.max(ba_arr))[0][0]
best_class_thresh = class_thresh_arr[best_ind]

print("Best balanced accuracy (no fairness constraints) = %.4f" % np.max(ba_arr))
print("Optimal classification threshold (no fairness constraints) = %.4f" % best_class_thresh)
# Out:
# Best balanced accuracy (no fairness constraints) = 0.9708
# Optimal classification threshold (no fairness constraints) = 0.4951

# %% [markdown]
# #### Estimate optimal parameters for the ROC method

# %%
ROC = RejectOptionClassification(unprivileged_groups=unprivileged_groups, 
                                 privileged_groups=privileged_groups, 
                                 low_class_thresh=0.01, high_class_thresh=0.99,
                                  num_class_thresh=100, num_ROC_margin=50,
                                  metric_name=metric_name,
                                  metric_ub=metric_ub, metric_lb=metric_lb)
ROC = ROC.fit(dataset_orig_valid, dataset_orig_valid_pred)

# %%
print("Optimal classification threshold (with fairness constraints) = %.4f" % ROC.classification_threshold)
print("Optimal ROC margin = %.4f" % ROC.ROC_margin)
# Out:
# Optimal classification threshold (with fairness constraints) = 0.0298
# Optimal ROC margin = 0.0012

# %% [markdown]
# ### Predictions from Validation Set

# %%
# Metrics for the test set
fav_inds = dataset_orig_valid_pred.scores > best_class_thresh
dataset_orig_valid_pred.labels[fav_inds] = dataset_orig_valid_pred.favorable_label
dataset_orig_valid_pred.labels[~fav_inds] = dataset_orig_valid_pred.unfavorable_label

display(Markdown("#### Validation set"))
display(Markdown("##### Raw predictions - No fairness constraints, only maximizing balanced accuracy"))

metric_valid_bef = compute_metrics(dataset_orig_valid, dataset_orig_valid_pred, 
                unprivileged_groups, privileged_groups)
# Out:
# #### Validation set
# ##### Raw predictions - No fairness constraints, only maximizing balanced accuracy
# Balanced accuracy = 0.9708
# Statistical parity difference = 0.0472
# Disparate impact = 1.0684
# Average odds difference = 0.0004
# Equal opportunity difference = -0.0034
# Theil index = 0.0381

# %%
# Transform the validation set
dataset_transf_valid_pred = ROC.predict(dataset_orig_valid_pred)

display(Markdown("#### Validation set"))
display(Markdown("##### Transformed predictions - With fairness constraints"))
metric_valid_aft = compute_metrics(dataset_orig_valid, dataset_transf_valid_pred, 
                unprivileged_groups, privileged_groups)
# Out:
# #### Validation set
# ##### Transformed predictions - With fairness constraints
# Balanced accuracy = 0.5392
# Statistical parity difference = 0.0273
# Disparate impact = 1.0283
# Average odds difference = 0.0448
# Equal opportunity difference = 0.0001
# Theil index = 0.0520

# %%
# Testing: Check if the metric optimized has not become worse
# assert np.abs(metric_valid_aft[metric_name]) <= np.abs(metric_valid_bef[metric_name])

# %% [markdown]
# ### Predictions from Original Test Set

# %%
display(Markdown("#### Predictions from original testing data"))
bal_acc_arr_orig = []
disp_imp_arr_orig = []
avg_odds_diff_arr_orig = []
spd_diff_arr_orig = []

print("Classification threshold used = %.4f" % best_class_thresh)
for thresh in tqdm(class_thresh_arr):
    
    if thresh == best_class_thresh:
        disp = True
    else:
        disp = False
    
    fav_inds = dataset_orig_test_pred.scores > thresh
    dataset_orig_test_pred.labels[fav_inds] = dataset_orig_test_pred.favorable_label
    dataset_orig_test_pred.labels[~fav_inds] = dataset_orig_test_pred.unfavorable_label
    
    metric_test_bef = compute_metrics(dataset_orig_test, dataset_orig_test_pred, 
                                      unprivileged_groups, privileged_groups,
                                      disp = disp)

    bal_acc_arr_orig.append(metric_test_bef["Balanced accuracy"])
    avg_odds_diff_arr_orig.append(metric_test_bef["Average odds difference"])
    disp_imp_arr_orig.append(metric_test_bef["Disparate impact"])
    spd_diff_arr_orig.append(metric_test_bef["Statistical parity difference"])
# Out:
# #### Predictions from original testing data
# Classification threshold used = 0.4951
#  51%|█████     | 51/100 [00:03<00:03, 14.27it/s]
# Balanced accuracy = 0.9706
# Statistical parity difference = 0.0458
# Disparate impact = 1.0662
# Average odds difference = -0.0002
# Equal opportunity difference = -0.0047
# Theil index = 0.0383
# 100%|██████████| 100/100 [00:07<00:00, 14.10it/s]

# %%
# inputs should be y_test, dataset_orig_test_pred.labels, dataset_orig_test_pred.scores respectively 
def accuracy_scores(y_true, preds, y_pred_scores, best_class_thresh):
    # F1 score
    y_pred = (y_pred_scores > best_class_thresh).astype(int)
    y_pred[y_pred == 1] = preds.favorable_label
    y_pred[y_pred == 0] = preds.unfavorable_label
    f1 = f1_score(y_true, y_pred)
    print(f"F1 Score: {f1:.4f}")
    # AUC
    auc = roc_auc_score(y_true, dataset_orig_test_pred.scores)
    print(f"ROC AUC Score: {auc:.4f}")
    
    return f1, auc

# %%
f1, auc = accuracy_scores(dataset_orig_test.labels, dataset_orig_test_pred, dataset_orig_test_pred.scores, best_class_thresh)
# Out:
# F1 Score: 0.9735
# ROC AUC Score: 0.9897

# %%
bias_summary_metrics(gender_col, dataset_orig_test_pred.labels)
# Out:
# Chi-Square Statistic: 349.61220383209206
# P-value: 5.147399150632928e-78
# There is a significant association between gender and loan approval.
# Z-statistic: 18.70338393483594
# P-value: 4.646051e-78
# There is a significant difference in loan approval rates between men and women.
# male approval rate: 0.7194202246023569
# female approval rate: 0.6768774703557312

# %%
# Metrics for the test set
fav_inds = dataset_orig_test_pred.scores > best_class_thresh
dataset_orig_test_pred.labels[fav_inds] = dataset_orig_test_pred.favorable_label
dataset_orig_test_pred.labels[~fav_inds] = dataset_orig_test_pred.unfavorable_label

display(Markdown("#### Test set"))
display(Markdown("##### Raw predictions - No fairness constraints, only maximizing balanced accuracy"))

metric_test_bef = compute_metrics(dataset_orig_test, dataset_orig_test_pred, 
                unprivileged_groups, privileged_groups)
# Out:
# #### Test set
# ##### Raw predictions - No fairness constraints, only maximizing balanced accuracy
# Balanced accuracy = 0.9706
# Statistical parity difference = 0.0458
# Disparate impact = 1.0662
# Average odds difference = -0.0002
# Equal opportunity difference = -0.0047
# Theil index = 0.0383

# %% [markdown]
# ### Graph Original Test Set

# %%
fig, ax1 = plt.subplots(figsize=(10,7))
ax1.plot(class_thresh_arr, bal_acc_arr_orig)
ax1.set_xlabel('Classification Thresholds', fontsize=16, fontweight='bold')
ax1.set_ylabel('Balanced Accuracy', color='b', fontsize=16, fontweight='bold')
ax1.xaxis.set_tick_params(labelsize=14)
ax1.yaxis.set_tick_params(labelsize=14)


ax2 = ax1.twinx()
ax2.plot(class_thresh_arr, np.abs(1.0-np.array(disp_imp_arr_orig)), color='r')
ax2.set_ylabel('abs(1-disparate impact)', color='r', fontsize=16, fontweight='bold')
ax2.axvline(best_class_thresh, color='k', linestyle=':')
ax2.yaxis.set_tick_params(labelsize=14)
ax2.grid(True)

plt.savefig("reject-xg-di-orig-nogen")

plt.show()

# %% [markdown]
# ```abs(1-disparate impact)``` must be small (close to 0) for classifier predictions to be fair.
#
# However, for a classifier trained with original training data, at the best classification rate, this is quite high. This implies unfairness.

# %%
fig, ax1 = plt.subplots(figsize=(10,7))
ax1.plot(class_thresh_arr, bal_acc_arr_orig)
ax1.set_xlabel('Classification Thresholds', fontsize=16, fontweight='bold')
ax1.set_ylabel('Balanced Accuracy', color='b', fontsize=16, fontweight='bold')
ax1.xaxis.set_tick_params(labelsize=14)
ax1.yaxis.set_tick_params(labelsize=14)


ax2 = ax1.twinx()
ax2.plot(class_thresh_arr, avg_odds_diff_arr_orig, color='r')
ax2.set_ylabel('avg. odds diff.', color='r', fontsize=16, fontweight='bold')
ax2.axvline(best_class_thresh, color='k', linestyle=':')
ax2.yaxis.set_tick_params(labelsize=14)
ax2.grid(True)

plt.savefig("reject-xg-aodds-orig-nogen")

plt.show()

# %% [markdown]
# ### Predictions from Transformed Test Set

# %%
# Metrics for the transformed test set
dataset_transf_test_pred = ROC.predict(dataset_orig_test_pred)

display(Markdown("#### Test set"))
display(Markdown("##### Transformed predictions - With fairness constraints"))
metric_test_aft = compute_metrics(dataset_orig_test, dataset_transf_test_pred, 
                unprivileged_groups, privileged_groups)
# Out:
# #### Test set
# ##### Transformed predictions - With fairness constraints
# Balanced accuracy = 0.5396
# Statistical parity difference = 0.0266
# Disparate impact = 1.0276
# Average odds difference = 0.0437
# Equal opportunity difference = 0.0001
# Theil index = 0.0519

# %%
display(Markdown("#### Predictions from transformed testing data"))
bal_acc_arr_transf = []
disp_imp_arr_transf = []
avg_odds_diff_arr_transf = []
spd_diff_arr_transf = []

print("Classification threshold used = %.4f" % best_class_thresh)
for thresh in tqdm(class_thresh_arr):
    
    if thresh == best_class_thresh:
        disp = True
    else:
        disp = False
    
    fav_inds = dataset_transf_test_pred.scores > thresh
    dataset_transf_test_pred.labels[fav_inds] = dataset_transf_test_pred.favorable_label
    dataset_transf_test_pred.labels[~fav_inds] = dataset_transf_test_pred.unfavorable_label
    
    metric_test_aft = compute_metrics(dataset_orig_test, dataset_transf_test_pred, 
                                      unprivileged_groups, privileged_groups,
                                      disp = disp)

    bal_acc_arr_transf.append(metric_test_aft["Balanced accuracy"])
    avg_odds_diff_arr_transf.append(metric_test_aft["Average odds difference"])
    disp_imp_arr_transf.append(metric_test_aft["Disparate impact"])
    spd_diff_arr_transf.append(metric_test_bef["Statistical parity difference"])
# Out:
# #### Predictions from transformed testing data
# Classification threshold used = 0.4951
#  52%|█████▏    | 52/100 [00:03<00:03, 14.56it/s]
# Balanced accuracy = 0.9706
# Statistical parity difference = 0.0458
# Disparate impact = 1.0662
# Average odds difference = -0.0002
# Equal opportunity difference = -0.0047
# Theil index = 0.0383
# 100%|██████████| 100/100 [00:06<00:00, 14.48it/s]

# %%
f1, auc = accuracy_scores(dataset_orig_test.labels, dataset_transf_test_pred, dataset_transf_test_pred.scores, ROC.classification_threshold)
# Out:
# F1 Score: 0.8685
# ROC AUC Score: 0.9897

# %%
bias_summary_metrics(gender_col, dataset_transf_test_pred.labels)
# Out:
# Chi-Square Statistic: 349.61220383209206
# P-value: 5.147399150632928e-78
# There is a significant association between gender and loan approval.
# Z-statistic: 18.70338393483594
# P-value: 4.646051e-78
# There is a significant difference in loan approval rates between men and women.
# male approval rate: 0.7194202246023569
# female approval rate: 0.6768774703557312

# %% [markdown]
# ### Graph Transformed Test Set

# %%
fig, ax1 = plt.subplots(figsize=(10,7))
ax1.plot(class_thresh_arr, bal_acc_arr_transf)
ax1.set_xlabel('Classification Thresholds', fontsize=16, fontweight='bold')
ax1.set_ylabel('Balanced Accuracy', color='b', fontsize=16, fontweight='bold')
ax1.xaxis.set_tick_params(labelsize=14)
ax1.yaxis.set_tick_params(labelsize=14)


ax2 = ax1.twinx()
ax2.plot(class_thresh_arr, np.abs(1.0-np.array(disp_imp_arr_transf)), color='r')
ax2.set_ylabel('abs(1-disparate impact)', color='r', fontsize=16, fontweight='bold')
ax2.axvline(best_class_thresh, color='k', linestyle=':')
ax2.yaxis.set_tick_params(labelsize=14)
ax2.grid(True)

plt.savefig("reject-xg-di-transf-nogen")

plt.show()

# %% [markdown]
# ```abs(1-disparate impact)``` must be small (close to 0) for classifier predictions to be fair.
#
# For a classifier trained with reweighted training data, at the best classification rate, this is indeed the case.
# This implies fairness.

# %%
fig, ax1 = plt.subplots(figsize=(10,7))
ax1.plot(class_thresh_arr, bal_acc_arr_transf)
ax1.set_xlabel('Classification Thresholds', fontsize=16, fontweight='bold')
ax1.set_ylabel('Balanced Accuracy', color='b', fontsize=16, fontweight='bold')
ax1.xaxis.set_tick_params(labelsize=14)
ax1.yaxis.set_tick_params(labelsize=14)


ax2 = ax1.twinx()
ax2.plot(class_thresh_arr, avg_odds_diff_arr_transf, color='r')
ax2.set_ylabel('avg. odds diff.', color='r', fontsize=16, fontweight='bold')
ax2.axvline(best_class_thresh, color='k', linestyle=':')
ax2.yaxis.set_tick_params(labelsize=14)
ax2.grid(True)

plt.savefig("reject-xg-aodds-transf-nogen")

plt.show()
